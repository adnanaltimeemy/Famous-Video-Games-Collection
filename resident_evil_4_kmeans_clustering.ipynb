# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resident_evil_4_enemies.csv")

df.head()
# Out:
#        Chapter                  Section     Name Voice Clothing Accessories  \
# 0  Chapter 1-1  Footpath to the Village     José   NaN      NaN         NaN
# 1  Chapter 1-1  Footpath to the Village   Manuel   NaN      NaN         NaN
# 2  Chapter 1-1  Footpath to the Village  Esteban   NaN      NaN         NaN
# 3  Chapter 1-1  Footpath to the Village    Diego   NaN      NaN         NaN
# 4  Chapter 1-1  Footpath to the Village  Esteban   NaN      NaN   Brown Hat
#
#           Weapon   Speed Rush  Health Plaga  \
# 0     Axe (Left)  Medium    ?     4.0   NaN
# 1  Sickle (Left)  Medium    ?     4.0   NaN
# 2            Axe    Fast    ?     4.0   NaN
# 3      Pitchfork    Slow    ?     4.0   NaN
# 4      Pitchfork    Slow    ?     4.0   NaN
#
#                                        Miscellaneous
# 0  Mandatory Kill. Cannot lose weapon. Does not t...
# 1  Defensive. Cannot lose weapon. Does not throw ...
# 2  Defensive. Cannot lose weapon. Does not throw ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Chapter        1068 non-null   str
#  1   Section        1068 non-null   str
#  2   Name           1068 non-null   str
#  3   Voice          288 non-null    str
#  4   Clothing       533 non-null    str
#  5   Accessories    466 non-null    str
#  6   Weapon         924 non-null    str
#  7   Speed          904 non-null    str
#  8   Rush           904 non-null    str
#  9   Health         1061 non-null   float64
#  10  Plaga          355 non-null    str
#  11  Miscellaneous  296 non-null    str
# dtypes: float64(1), str(11)
# memory usage: 174.2 KB

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Chapter'
# 'Section'
# 'Name'
# 'Voice'
# 'Clothing'
# 'Accessories'
# 'Weapon'
# 'Speed'
# 'Rush'
# 'Health'
# 'Plaga'
# 'Miscellaneous'

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Example dataset
data = {
    'age': [25, 32, 47, 51, 62],
    'salary': [50000, 64000, 120000, 110000, 150000],
    'experience': [2, 5, 20, 25, 30]
}

# Create DataFrame
df = pd.DataFrame(data)

# Select features
features = df

# Initialize scaler
scaler = StandardScaler()

# Scale features
scaled_features = scaler.fit_transform(features)

# Convert back to DataFrame (optional but useful)
scaled_df = pd.DataFrame(scaled_features, columns=features.columns)

# Show first 5 rows
print(scaled_df.head())
# Out:
#         age    salary  experience
# 0 -1.382872 -1.324367   -1.304570
# 1 -0.856780 -0.944426   -1.032785
# 2  0.270562  0.575340    0.326143
# 3  0.571186  0.303953    0.779118
# 4  1.397904  1.389500    1.232094

# %%
print(scaled_features.shape)
# Out:
# (5, 3)

# %%
df.head()
# Out:
#    age  salary  experience
# 0   25   50000           2
# 1   32   64000           5
# 2   47  120000          20
# 3   51  110000          25
# 4   62  150000          30

# %%
print(df.head())
print(df.columns)
# Out:
#    age  salary  experience
# 0   25   50000           2
# 1   32   64000           5
# 2   47  120000          20
# 3   51  110000          25
# 4   62  150000          30
# Index(['age', 'salary', 'experience'], dtype='str')

# %%
model = KMeans(n_clusters=3)
model.fit(scaled_features)
# Out:
# KMeans(n_clusters=3)

# %%
df.to_csv("resident_evil_4_enemy_clusters.csv", index=False)
