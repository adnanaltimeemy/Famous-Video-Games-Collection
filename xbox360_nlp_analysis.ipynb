# %%
# Data handling
import pandas as pd
import numpy as np

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Machine Learning / NLP tools
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.cluster import KMeans

# %%
# Load CSV file
df = pd.read_csv("xbox360_gamelist.csv")

# Preview the dataset
df.head()
# Out:
#            Game Name  Title ID   Serial  ...   XEX CRC  Media ID  Wave
# 0           NBA 2K16  315A07D1  1Z-2001  ...  E2A1A2F4  3AC236C5  XGD3
# 1           WWE 2K16  315A07D2  1Z-2002  ...  697B2F76  51FE55C7  XGD3
# 2   Love Tore: Sweet  324707D1  2G-2001  ...  8EA4D2A1  52F19F68    16
# 3    Love Tore: Mint  324707D2  2G-2002  ...  784C3C01  55E69D1B    16
# 4  Love Tore: Bitter  324707D3  2G-2003  ...  BD4C676E  4B370D6E    16
#
# [5 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Game Name', 'Title ID', 'Serial', 'Type', 'Region', 'XEX CRC',
#        'Media ID', 'Wave'],
#       dtype='str')

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')

df = pd.DataFrame({
    "text": ["This is a sentence.", "Tokenizing text is useful."]
})

text_data = df["text"]
tokens = text_data.apply(word_tokenize)

tokens.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0           [This, is, a, sentence, .]
# 1    [Tokenizing, text, is, useful, .]
# Name: text, dtype: object

# %%
vectorizer = CountVectorizer(stop_words='english')

X = vectorizer.fit_transform(text_data)

print(X.shape)
# Out:
# (2, 4)

# %%
tfidf = TfidfVectorizer(stop_words='english')

X_tfidf = tfidf.fit_transform(text_data)

print(X_tfidf.shape)
# Out:
# (2, 4)

# %%
word_counts = np.asarray(X.sum(axis=0)).flatten()

words = vectorizer.get_feature_names_out()

word_freq = pd.DataFrame({
    'word': words,
    'frequency': word_counts
})

word_freq = word_freq.sort_values(by='frequency', ascending=False)

word_freq.head(10)
# Out:
#          word  frequency
# 0    sentence          1
# 1        text          1
# 2  tokenizing          1
# 3      useful          1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

documents = ["text data example", "another document", "machine learning clustering"]

tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(documents)

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(tfidf_matrix)

order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = tfidf.get_feature_names_out()

for i in range(2):
    print(f"Cluster {i}:")
    for ind in order_centroids[i, :10]:
        print(terms[ind])
    print()
# Out:
# Cluster 0:
# document
# text
# example
# data
# machine
# learning
# clustering
#
# Cluster 1:
# machine
# learning
# clustering
# text
# example
# document
# data
