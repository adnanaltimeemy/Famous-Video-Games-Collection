# %%
# Import required libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("odyssey.csv")

# Display first few rows
df.head()
# Out:
#    Book                         Title  \
# 0     1    Athena Inspires the Prince
# 1     2          Telemachus Sets Sail
# 2     3         King Nestor Remembers
# 3     4  The King and Queen of Sparta
# 4     5       Odysseus Leaves Calypso
#
#                                           Main_Event  \
# 0                  Telemachus seeks news of Odysseus
# 1      Telemachus secretly leaves to find his father
# 2             Nestor tells stories of the Trojan War
# 3           Menelaus recounts Odysseus being trapped
# 4  Calypso releases Odysseus after years of capti...
#
#                Key_Characters Location
# 0  Athena Telemachus Penelope   Ithaca
# 1           Telemachus Athena   Ithaca
# 2           Nestor Telemachus    Pylos
# 3   Menelaus Helen Telemachus   Sparta
# 4     Odysseus Calypso Hermes   Ogygia

# %%
df.columns
# Out:
# Index(['Book', 'Title', 'Main_Event', 'Key_Characters', 'Location'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32']

# %%
df.head()
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Book', 'Title', 'Main_Event', 'Key_Characters', 'Location'], dtype='str')

# %%
print(dir())
# Out:
# ['DecisionTreeClassifier', 'In', 'Out', 'RandomForestClassifier', '_', '_14', '_3', '_6', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'classification_report', 'df', 'dt_model', 'exit', 'get_ipython', 'np', 'open', 'pd', 'plot_tree', 'plt', 'quit', 'train_test_split']

# %%
import pandas as pd

df = pd.read_csv("odyssey.csv")

print(df.columns)
# Out:
# Index(['Book', 'Title', 'Main_Event', 'Key_Characters', 'Location'], dtype='str')

# %%
print(dir())
# Out:
# ['DecisionTreeClassifier', 'In', 'Out', 'RandomForestClassifier', '_', '_14', '_3', '_6', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'classification_report', 'df', 'dt_model', 'exit', 'get_ipython', 'np', 'open', 'pd', 'plot_tree', 'plt', 'quit', 'rf_model', 'train_test_split']

# %%
df.columns
# Out:
# Index(['Book', 'Title', 'Main_Event', 'Key_Characters', 'Location'], dtype='str')

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
